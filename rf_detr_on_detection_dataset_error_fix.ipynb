# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time, transformer-based object detection model architecture developed by Roboflow and released under the Apache 2.0 license.
#
# ![rf-detr-coco-rf100-vl-8](https://media.roboflow.com/rf-detr/charts.png)
#
# RF-DETR is the first real-time model to exceed 60 AP on the [Microsoft COCO benchmark](https://cocodataset.org/#home) alongside competitive performance at base sizes. It also achieves state-of-the-art performance on [RF100-VL](https://github.com/roboflow/rf100-vl), an object detection benchmark that measures model domain adaptability to real world problems. RF-DETR is comparable speed to current real-time objection models.
#
# ![rf-detr-coco-results-2](https://media.roboflow.com/rf-detr/example_grid.png)
#
# RF-DETR is small enough to run on the edge, making it an ideal model for deployments that need both strong accuracy and real-time performance.

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API keys
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Open your [`HuggingFace Settings`](https://huggingface.co/settings) page. Click `Access Tokens` then `New Token` to generate new token.
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy`. This will place your private key in the clipboard.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store HuggingFace Access Token under the name `HF_TOKEN`.
#     - Store Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = ""
os.environ["ROBOFLOW_API_KEY"] = ""

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sat Apr  5 15:17:59 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies

# %%
# !pip install -q rfdetr
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 8.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 89.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 70.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.9/354.9 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 14.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.5/765.5 kB 44.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.6 MB/s eta 0:00:00
#   Building wheel for fairscale (pyproject.toml) ... done

# %% [markdown]
# ### Download example data

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %%
from rfdetr import RFDETRBase
from rfdetr.util.coco_classes import COCO_CLASSES
import supervision as sv
import numpy as np
from PIL import Image

image = Image.open("dog-2.jpeg")

model = RFDETRBase()
detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image
# Out:
# rf-detr-base.pth: 100%|██████████| 355M/355M [00:09<00:00, 40.2MiB/s]
# UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]
# Loading pretrain weights
# UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:3637.)
# <PIL.Image.Image image mode=RGB size=720x1280>

# %% [markdown]
# ## Download dataset from Roboflow Universe

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="EHOn7R5Jmi11PxeMpSMH")
project = rf.workspace("university-f1igv").project("fer2025_ml_project")
version = project.version(6)
dataset = version.download("coco")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.1.60)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.1.0)
# Requirement already satisfied: pillow-heif>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.22.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.56.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in FER2025_ML_Project-6 to coco:: 100%|██████████| 62656/62656 [00:02<00:00, 24118.65it/s]
# Extracting Dataset Version Zip to FER2025_ML_Project-6 in coco:: 100%|██████████| 1951/1951 [00:00<00:00, 4973.99it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.
#
# ### Train with multiple GPUs
#
# You can fine-tune RF-DETR on multiple GPUs using PyTorch’s Distributed Data Parallel (DDP). Create a `main.py` script that initializes your model and calls `.train()` as usual than run it in terminal.
#
# ```bash
# python -m torch.distributed.launch \
#     --nproc_per_node=8 \
#     --use_env \
#     main.py
# ```
#
# Replace `8` in the `--nproc_per_node argument` with the number of GPUs you want to use. This approach creates one training process per GPU and splits the workload automatically. Note that your effective batch size is multiplied by the number of GPUs, so you may need to adjust your `batch_size` and `grad_accum_steps` to maintain the same overall batch size.

# %%
import os
from rfdetr import RFDETRBase

# Initialize model
model = RFDETRBase()

# Optional callback to track training
history = []
def callback2(data):
    history.append(data)
model.callbacks["on_fit_epoch_end"].append(callback2)

# Train with lower batch size & gradient checkpointing
model.train(
    dataset_dir="/content/FER2025_ML_Project-6",
    epochs=1,
    batch_size=4,               # Reduced to fit GPU
    grad_accum_steps=1,
    lr=1e-4,
    gradient_checkpointing=True,
    amp=True
)
# Out:
# Loading pretrain weights
# WARNING:rfdetr.detr:num_classes mismatch: model has 90 classes, but your dataset has 13 classes
# reinitializing your detection head with 13 classes.
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=13, grad_accum_steps=1, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=4, weight_decay=0.0001, epochs=1, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-base.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[2, 5, 8, 11], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=3, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/FER2025_ML_Project-6', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume='', start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=560, use_cls_token=False, multi_scale=True, expanded_scales=True, warmup_epochs=0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=True, tensorboard=True, wandb=False, project=None, run=None, class_names=['angry_female', 'angry_male', 'fear_female', 'fear_male', 'happy_female', 'happy_male', 'sad_female', 'sad_male', 'sleepy_female', 'sleepy_male', 'surprised_female', 'surprised_male'], distributed=False)
# number of params: 31893886
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [392, 448, 504, 560, 616, 672, 728, 784]
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  1
# Total batch size:  4
# LENGTH OF DATA LOADER: 340
# Epoch: [0]  [  0/340]  eta: 0:21:34  lr: 0.000100  class_error: 65.93  loss: 22.0170 (22.0170)  loss_ce: 0.6413 (0.6413)  loss_bbox: 3.0599 (3.0599)  loss_giou: 1.6854 (1.6854)  loss_ce_0: 0.5926 (0.5926)  loss_bbox_0: 3.2486 (3.2486)  loss_giou_0: 1.7552 (1.7552)  loss_ce_1: 0.6434 (0.6434)  loss_bbox_1: 3.0896 (3.0896)  loss_giou_1: 1.6834 (1.6834)  loss_ce_enc: 0.6081 (0.6081)  loss_bbox_enc: 3.2313 (3.2313)  loss_giou_enc: 1.7782 (1.7782)  loss_ce_unscaled: 0.6413 (0.6413)  class_error_unscaled: 65.9341 (65.9341)  loss_bbox_unscaled: 0.6120 (0.6120)  loss_giou_unscaled: 0.8427 (0.8427)  cardinality_error_unscaled: 3744.7500 (3744.7500)  loss_ce_0_unscaled: 0.5926 (0.5926)  loss_bbox_0_unscaled: 0.6497 (0.6497)  loss_giou_0_unscaled: 0.8776 (0.8776)  cardinality_error_0_unscaled: 3884.2500 (3884.2500)  loss_ce_1_unscaled: 0.6434 (0.6434)  loss_bbox_1_unscaled: 0.6179 (0.6179)  loss_giou_1_unscaled: 0.8417 (0.8417)  cardinality_error_1_unscaled: 3854.2500 (3854.2500)  loss_ce_enc_unscaled: 0.6081 (0.6081)  loss_bbox_enc_unscaled: 0.6463 (0.6463)  loss_giou_enc_unscaled: 0.8891 (0.8891)  cardinality_error_enc_unscaled: 3543.7500 (3543.7500)  time: 3.8069  data: 0.8386  max mem: 6441
# Epoch: [0]  [ 10/340]  eta: 0:10:50  lr: 0.000100  class_error: 95.10  loss: 19.5807 (19.5418)  loss_ce: 0.8246 (0.8092)  loss_bbox: 2.7774 (2.6769)  loss_giou: 1.2452 (1.2799)  loss_ce_0: 0.7893 (0.7793)  loss_bbox_0: 2.9135 (2.7875)  loss_giou_0: 1.2789 (1.3342)  loss_ce_1: 0.8193 (0.8072)  loss_bbox_1: 2.8369 (2.7035)  loss_giou_1: 1.2635 (1.2918)  loss_ce_enc: 0.7656 (0.7677)  loss_bbox_enc: 2.9715 (2.9023)  loss_giou_enc: 1.3595 (1.4023)  loss_ce_unscaled: 0.8246 (0.8092)  class_error_unscaled: 91.0256 (85.1488)  loss_bbox_unscaled: 0.5555 (0.5354)  loss_giou_unscaled: 0.6226 (0.6399)  cardinality_error_unscaled: 3766.2500 (3753.8864)  loss_ce_0_unscaled: 0.7893 (0.7793)  loss_bbox_0_unscaled: 0.5827 (0.5575)  loss_giou_0_unscaled: 0.6395 (0.6671)  cardinality_error_0_unscaled: 3867.2500 (3871.5682)  loss_ce_1_unscaled: 0.8193 (0.8072)  loss_bbox_1_unscaled: 0.5674 (0.5407)  loss_giou_1_unscaled: 0.6317 (0.6459)  cardinality_error_1_unscaled: 3874.0000 (3873.2500)  loss_ce_enc_unscaled: 0.7656 (0.7677)  loss_bbox_enc_unscaled: 0.5943 (0.5805)  loss_giou_enc_unscaled: 0.6798 (0.7012)  cardinality_error_enc_unscaled: 3533.7500 (3530.7273)  time: 1.9721  data: 0.0964  max mem: 9119
# Epoch: [0]  [ 20/340]  eta: 0:09:31  lr: 0.000100  class_error: 98.90  loss: 15.8619 (17.0581)  loss_ce: 0.9270 (0.9184)  loss_bbox: 1.9293 (2.1565)  loss_giou: 1.0072 (1.0581)  loss_ce_0: 0.9168 (0.8951)  loss_bbox_0: 2.0972 (2.2623)  loss_giou_0: 1.0616 (1.1050)  loss_ce_1: 0.9337 (0.9186)  loss_bbox_1: 2.0093 (2.1857)  loss_giou_1: 0.9931 (1.0687)  loss_ce_enc: 0.8627 (0.8542)  loss_bbox_enc: 2.2522 (2.4257)  loss_giou_enc: 1.1324 (1.2100)  loss_ce_unscaled: 0.9270 (0.9184)  class_error_unscaled: 92.3077 (89.1618)  loss_bbox_unscaled: 0.3859 (0.4313)  loss_giou_unscaled: 0.5036 (0.5291)  cardinality_error_unscaled: 3709.7500 (3713.6071)  loss_ce_0_unscaled: 0.9168 (0.8951)  loss_bbox_0_unscaled: 0.4194 (0.4525)  loss_giou_0_unscaled: 0.5308 (0.5525)  cardinality_error_0_unscaled: 3848.0000 (3842.3810)  loss_ce_1_unscaled: 0.9337 (0.9186)  loss_bbox_1_unscaled: 0.4019 (0.4371)  loss_giou_1_unscaled: 0.4966 (0.5343)  cardinality_error_1_unscaled: 3858.7500 (3851.5714)  loss_ce_enc_unscaled: 0.8627 (0.8542)  loss_bbox_enc_unscaled: 0.4504 (0.4851)  loss_giou_enc_unscaled: 0.5662 (0.6050)  cardinality_error_enc_unscaled: 3560.7500 (3559.6905)  time: 1.6846  data: 0.0188  max mem: 9119
# Epoch: [0]  [ 30/340]  eta: 0:08:46  lr: 0.000100  class_error: 90.77  loss: 12.6132 (15.1446)  loss_ce: 1.1055 (1.0054)  loss_bbox: 1.1824 (1.7599)  loss_giou: 0.6394 (0.8878)  loss_ce_0: 1.0844 (0.9809)  loss_bbox_0: 1.2994 (1.8698)  loss_giou_0: 0.6768 (0.9335)  loss_ce_1: 1.1132 (1.0080)  loss_bbox_1: 1.1979 (1.7780)  loss_giou_1: 0.6240 (0.8905)  loss_ce_enc: 1.0071 (0.9272)  loss_bbox_enc: 1.4760 (2.0498)  loss_giou_enc: 0.8641 (1.0537)  loss_ce_unscaled: 1.1055 (1.0054)  class_error_unscaled: 95.6044 (90.4319)  loss_bbox_unscaled: 0.2365 (0.3520)  loss_giou_unscaled: 0.3197 (0.4439)  cardinality_error_unscaled: 3560.5000 (3607.1048)  loss_ce_0_unscaled: 1.0844 (0.9809)  loss_bbox_0_unscaled: 0.2599 (0.3740)  loss_giou_0_unscaled: 0.3384 (0.4668)  cardinality_error_0_unscaled: 3808.2500 (3832.1855)  loss_ce_1_unscaled: 1.1132 (1.0080)  loss_bbox_1_unscaled: 0.2396 (0.3556)  loss_giou_1_unscaled: 0.3120 (0.4453)  cardinality_error_1_unscaled: 3813.0000 (3834.9113)  loss_ce_enc_unscaled: 1.0071 (0.9272)  loss_bbox_enc_unscaled: 0.2952 (0.4100)  loss_giou_enc_unscaled: 0.4321 (0.5269)  cardinality_error_enc_unscaled: 3560.7500 (3554.8145)  time: 1.5495  data: 0.0161  max mem: 9120
# Epoch: [0]  [ 40/340]  eta: 0:08:34  lr: 0.000100  class_error: 92.31  loss: 10.2971 (13.8870)  loss_ce: 1.2119 (1.0580)  loss_bbox: 0.7735 (1.4990)  loss_giou: 0.4735 (0.7923)  loss_ce_0: 1.1630 (1.0328)  loss_bbox_0: 0.8646 (1.5954)  loss_giou_0: 0.5588 (0.8382)  loss_ce_1: 1.2113 (1.0600)  loss_bbox_1: 0.7514 (1.5095)  loss_giou_1: 0.4731 (0.7947)  loss_ce_enc: 1.1198 (0.9737)  loss_bbox_enc: 1.0264 (1.7729)  loss_giou_enc: 0.6597 (0.9604)  loss_ce_unscaled: 1.2119 (1.0580)  class_error_unscaled: 92.3077 (89.2061)  loss_bbox_unscaled: 0.1547 (0.2998)  loss_giou_unscaled: 0.2367 (0.3962)  cardinality_error_unscaled: 3152.5000 (3447.8293)  loss_ce_0_unscaled: 1.1630 (1.0328)  loss_bbox_0_unscaled: 0.1729 (0.3191)  loss_giou_0_unscaled: 0.2794 (0.4191)  cardinality_error_0_unscaled: 3815.0000 (3830.6707)  loss_ce_1_unscaled: 1.2113 (1.0600)  loss_bbox_1_unscaled: 0.1503 (0.3019)  loss_giou_1_unscaled: 0.2365 (0.3974)  cardinality_error_1_unscaled: 3787.7500 (3817.4939)  loss_ce_enc_unscaled: 1.1198 (0.9737)  loss_bbox_enc_unscaled: 0.2053 (0.3546)  loss_giou_enc_unscaled: 0.3298 (0.4802)  cardinality_error_enc_unscaled: 3540.0000 (3550.6159)  time: 1.6380  data: 0.0160  max mem: 9120
# Epoch: [0]  [ 50/340]  eta: 0:08:20  lr: 0.000100  class_error: 90.77  loss: 8.9563 (12.8902)  loss_ce: 1.2834 (1.1061)  loss_bbox: 0.4814 (1.2911)  loss_giou: 0.3824 (0.7064)  loss_ce_0: 1.2404 (1.0774)  loss_bbox_0: 0.5523 (1.3847)  loss_giou_0: 0.4409 (0.7549)  loss_ce_1: 1.2752 (1.1071)  loss_bbox_1: 0.4798 (1.3012)  loss_giou_1: 0.3747 (0.7095)  loss_ce_enc: 1.1792 (1.0186)  loss_bbox_enc: 0.7404 (1.5595)  loss_giou_enc: 0.5650 (0.8735)  loss_ce_unscaled: 1.2834 (1.1061)  class_error_unscaled: 90.3846 (88.8548)  loss_bbox_unscaled: 0.0963 (0.2582)  loss_giou_unscaled: 0.1912 (0.3532)  cardinality_error_unscaled: 3094.2500 (3391.7794)  loss_ce_0_unscaled: 1.2404 (1.0774)  loss_bbox_0_unscaled: 0.1105 (0.2769)  loss_giou_0_unscaled: 0.2204 (0.3775)  cardinality_error_0_unscaled: 3810.7500 (3816.9167)  loss_ce_1_unscaled: 1.2752 (1.1071)  loss_bbox_1_unscaled: 0.0960 (0.2602)  loss_giou_1_unscaled: 0.1873 (0.3547)  cardinality_error_1_unscaled: 3757.5000 (3803.7745)  loss_ce_enc_unscaled: 1.1792 (1.0186)  loss_bbox_enc_unscaled: 0.1481 (0.3119)  loss_giou_enc_unscaled: 0.2825 (0.4368)  cardinality_error_enc_unscaled: 3530.2500 (3544.2255)  time: 1.7697  data: 0.0163  max mem: 9120
# Epoch: [0]  [ 60/340]  eta: 0:08:04  lr: 0.000100  class_error: 78.85  loss: 8.4272 (12.1192)  loss_ce: 1.3091 (1.1400)  loss_bbox: 0.3695 (1.1326)  loss_giou: 0.3445 (0.6456)  loss_ce_0: 1.2712 (1.1108)  loss_bbox_0: 0.4374 (1.2207)  loss_giou_0: 0.3817 (0.6920)  loss_ce_1: 1.2984 (1.1403)  loss_bbox_1: 0.3700 (1.1414)  loss_giou_1: 0.3534 (0.6481)  loss_ce_enc: 1.2143 (1.0510)  loss_bbox_enc: 0.5904 (1.3875)  loss_giou_enc: 0.4865 (0.8091)  loss_ce_unscaled: 1.3091 (1.1400)  class_error_unscaled: 84.6154 (87.6579)  loss_bbox_unscaled: 0.0739 (0.2265)  loss_giou_unscaled: 0.1723 (0.3228)  cardinality_error_unscaled: 3047.0000 (3313.2746)  loss_ce_0_unscaled: 1.2712 (1.1108)  loss_bbox_0_unscaled: 0.0875 (0.2441)  loss_giou_0_unscaled: 0.1908 (0.3460)  cardinality_error_0_unscaled: 3719.0000 (3798.0287)  loss_ce_1_unscaled: 1.2984 (1.1403)  loss_bbox_1_unscaled: 0.0740 (0.2283)  loss_giou_1_unscaled: 0.1767 (0.3241)  cardinality_error_1_unscaled: 3691.7500 (3780.3689)  loss_ce_enc_unscaled: 1.2143 (1.0510)  loss_bbox_enc_unscaled: 0.1181 (0.2775)  loss_giou_enc_unscaled: 0.2432 (0.4045)  cardinality_error_enc_unscaled: 3506.5000 (3537.8156)  time: 1.7619  data: 0.0165  max mem: 9121
# Epoch: [0]  [ 70/340]  eta: 0:07:45  lr: 0.000100  class_error: 86.15  loss: 8.1665 (11.5471)  loss_ce: 1.3658 (1.1782)  loss_bbox: 0.3149 (1.0168)  loss_giou: 0.2890 (0.5906)  loss_ce_0: 1.3176 (1.1444)  loss_bbox_0: 0.3628 (1.0978)  loss_giou_0: 0.3079 (0.6336)  loss_ce_1: 1.3470 (1.1739)  loss_bbox_1: 0.3205 (1.0272)  loss_giou_1: 0.2691 (0.5941)  loss_ce_enc: 1.2514 (1.0848)  loss_bbox_enc: 0.4870 (1.2588)  loss_giou_enc: 0.4198 (0.7470)  loss_ce_unscaled: 1.3658 (1.1782)  class_error_unscaled: 84.6154 (87.0684)  loss_bbox_unscaled: 0.0630 (0.2034)  loss_giou_unscaled: 0.1445 (0.2953)  cardinality_error_unscaled: 3059.0000 (3293.5493)  loss_ce_0_unscaled: 1.3176 (1.1444)  loss_bbox_0_unscaled: 0.0726 (0.2196)  loss_giou_0_unscaled: 0.1540 (0.3168)  cardinality_error_0_unscaled: 3767.0000 (3801.7782)  loss_ce_1_unscaled: 1.3470 (1.1739)  loss_bbox_1_unscaled: 0.0641 (0.2054)  loss_giou_1_unscaled: 0.1345 (0.2970)  cardinality_error_1_unscaled: 3691.7500 (3771.6373)  loss_ce_enc_unscaled: 1.2514 (1.0848)  loss_bbox_enc_unscaled: 0.0974 (0.2518)  loss_giou_enc_unscaled: 0.2099 (0.3735)  cardinality_error_enc_unscaled: 3552.0000 (3548.9120)  time: 1.7202  data: 0.0149  max mem: 9121
# Epoch: [0]  [ 80/340]  eta: 0:07:29  lr: 0.000100  class_error: 67.95  loss: 7.9237 (11.1290)  loss_ce: 1.3778 (1.1980)  loss_bbox: 0.2917 (0.9347)  loss_giou: 0.2605 (0.5596)  loss_ce_0: 1.3480 (1.1654)  loss_bbox_0: 0.3302 (1.0074)  loss_giou_0: 0.2677 (0.5983)  loss_ce_1: 1.3575 (1.1947)  loss_bbox_1: 0.3017 (0.9401)  loss_giou_1: 0.2662 (0.5603)  loss_ce_enc: 1.2775 (1.1065)  loss_bbox_enc: 0.4345 (1.1574)  loss_giou_enc: 0.3829 (0.7067)  loss_ce_unscaled: 1.3778 (1.1980)  class_error_unscaled: 81.5385 (85.9538)  loss_bbox_unscaled: 0.0583 (0.1869)  loss_giou_unscaled: 0.1303 (0.2798)  cardinality_error_unscaled: 3235.0000 (3296.3519)  loss_ce_0_unscaled: 1.3480 (1.1654)  loss_bbox_0_unscaled: 0.0660 (0.2015)  loss_giou_0_unscaled: 0.1339 (0.2991)  cardinality_error_0_unscaled: 3854.5000 (3808.8642)  loss_ce_1_unscaled: 1.3575 (1.1947)  loss_bbox_1_unscaled: 0.0603 (0.1880)  loss_giou_1_unscaled: 0.1331 (0.2801)  cardinality_error_1_unscaled: 3756.5000 (3772.4753)  loss_ce_enc_unscaled: 1.2775 (1.1065)  loss_bbox_enc_unscaled: 0.0869 (0.2315)  loss_giou_enc_unscaled: 0.1915 (0.3533)  cardinality_error_enc_unscaled: 3653.7500 (3565.8580)  time: 1.7304  data: 0.0158  max mem: 9121
# Epoch: [0]  [ 90/340]  eta: 0:07:10  lr: 0.000100  class_error: 69.23  loss: 7.9237 (10.7731)  loss_ce: 1.3981 (1.2243)  loss_bbox: 0.2878 (0.8638)  loss_giou: 0.2605 (0.5235)  loss_ce_0: 1.3827 (1.1921)  loss_bbox_0: 0.3059 (0.9294)  loss_giou_0: 0.2586 (0.5582)  loss_ce_1: 1.3828 (1.2203)  loss_bbox_1: 0.2658 (0.8666)  loss_giou_1: 0.2529 (0.5233)  loss_ce_enc: 1.2967 (1.1295)  loss_bbox_enc: 0.4212 (1.0757)  loss_giou_enc: 0.3654 (0.6663)  loss_ce_unscaled: 1.3981 (1.2243)  class_error_unscaled: 81.5385 (85.4686)  loss_bbox_unscaled: 0.0576 (0.1728)  loss_giou_unscaled: 0.1303 (0.2618)  cardinality_error_unscaled: 3331.7500 (3309.6731)  loss_ce_0_unscaled: 1.3827 (1.1921)  loss_bbox_0_unscaled: 0.0612 (0.1859)  loss_giou_0_unscaled: 0.1293 (0.2791)  cardinality_error_0_unscaled: 3854.2500 (3811.9396)  loss_ce_1_unscaled: 1.3828 (1.2203)  loss_bbox_1_unscaled: 0.0532 (0.1733)  loss_giou_1_unscaled: 0.1264 (0.2617)  cardinality_error_1_unscaled: 3798.2500 (3776.4148)  loss_ce_enc_unscaled: 1.2967 (1.1295)  loss_bbox_enc_unscaled: 0.0842 (0.2151)  loss_giou_enc_unscaled: 0.1827 (0.3332)  cardinality_error_enc_unscaled: 3689.7500 (3579.3324)  time: 1.7135  data: 0.0160  max mem: 9121
# Epoch: [0]  [100/340]  eta: 0:06:51  lr: 0.000100  class_error: 81.32  loss: 7.8283 (10.4786)  loss_ce: 1.4242 (1.2429)  loss_bbox: 0.2761 (0.8050)  loss_giou: 0.2420 (0.4977)  loss_ce_0: 1.3949 (1.2107)  loss_bbox_0: 0.2827 (0.8647)  loss_giou_0: 0.2527 (0.5290)  loss_ce_1: 1.4325 (1.2387)  loss_bbox_1: 0.2518 (0.8052)  loss_giou_1: 0.2322 (0.4959)  loss_ce_enc: 1.3228 (1.1478)  loss_bbox_enc: 0.3849 (1.0063)  loss_giou_enc: 0.3178 (0.6346)  loss_ce_unscaled: 1.4242 (1.2429)  class_error_unscaled: 83.3333 (85.2354)  loss_bbox_unscaled: 0.0552 (0.1610)  loss_giou_unscaled: 0.1210 (0.2488)  cardinality_error_unscaled: 3462.7500 (3325.6807)  loss_ce_0_unscaled: 1.3949 (1.2107)  loss_bbox_0_unscaled: 0.0565 (0.1729)  loss_giou_0_unscaled: 0.1263 (0.2645)  cardinality_error_0_unscaled: 3838.7500 (3814.2970)  loss_ce_1_unscaled: 1.4325 (1.2387)  loss_bbox_1_unscaled: 0.0504 (0.1610)  loss_giou_1_unscaled: 0.1161 (0.2479)  cardinality_error_1_unscaled: 3808.0000 (3779.5149)  loss_ce_enc_unscaled: 1.3228 (1.1478)  loss_bbox_enc_unscaled: 0.0770 (0.2013)  loss_giou_enc_unscaled: 0.1589 (0.3173)  cardinality_error_enc_unscaled: 3682.2500 (3586.1733)  time: 1.6589  data: 0.0148  max mem: 9121
# Epoch: [0]  [110/340]  eta: 0:06:30  lr: 0.000100  class_error: 76.92  loss: 7.7835 (10.2374)  loss_ce: 1.4056 (1.2587)  loss_bbox: 0.2559 (0.7569)  loss_giou: 0.2637 (0.4760)  loss_ce_0: 1.3813 (1.2271)  loss_bbox_0: 0.2644 (0.8099)  loss_giou_0: 0.2550 (0.5040)  loss_ce_1: 1.4254 (1.2549)  loss_bbox_1: 0.2436 (0.7549)  loss_giou_1: 0.2345 (0.4727)  loss_ce_enc: 1.3228 (1.1639)  loss_bbox_enc: 0.3567 (0.9505)  loss_giou_enc: 0.3256 (0.6079)  loss_ce_unscaled: 1.4056 (1.2587)  class_error_unscaled: 81.5385 (84.7947)  loss_bbox_unscaled: 0.0512 (0.1514)  loss_giou_unscaled: 0.1318 (0.2380)  cardinality_error_unscaled: 3584.5000 (3356.9730)  loss_ce_0_unscaled: 1.3813 (1.2271)  loss_bbox_0_unscaled: 0.0529 (0.1620)  loss_giou_0_unscaled: 0.1275 (0.2520)  cardinality_error_0_unscaled: 3837.0000 (3816.5586)  loss_ce_1_unscaled: 1.4254 (1.2549)  loss_bbox_1_unscaled: 0.0487 (0.1510)  loss_giou_1_unscaled: 0.1173 (0.2364)  cardinality_error_1_unscaled: 3833.7500 (3785.8198)  loss_ce_enc_unscaled: 1.3228 (1.1639)  loss_bbox_enc_unscaled: 0.0713 (0.1901)  loss_giou_enc_unscaled: 0.1628 (0.3040)  cardinality_error_enc_unscaled: 3696.7500 (3602.5541)  time: 1.5823  data: 0.0151  max mem: 9121
# Epoch: [0]  [120/340]  eta: 0:06:13  lr: 0.000100  class_error: 78.46  loss: 7.7736 (10.0470)  loss_ce: 1.3821 (1.2695)  loss_bbox: 0.2581 (0.7226)  loss_giou: 0.2393 (0.4574)  loss_ce_0: 1.3908 (1.2411)  loss_bbox_0: 0.2634 (0.7690)  loss_giou_0: 0.2169 (0.4821)  loss_ce_1: 1.4310 (1.2697)  loss_bbox_1: 0.2508 (0.7164)  loss_giou_1: 0.1943 (0.4521)  loss_ce_enc: 1.3517 (1.1795)  loss_bbox_enc: 0.3555 (0.9046)  loss_giou_enc: 0.3018 (0.5829)  loss_ce_unscaled: 1.3821 (1.2695)  class_error_unscaled: 78.8462 (84.2543)  loss_bbox_unscaled: 0.0516 (0.1445)  loss_giou_unscaled: 0.1196 (0.2287)  cardinality_error_unscaled: 3698.5000 (3390.2004)  loss_ce_0_unscaled: 1.3908 (1.2411)  loss_bbox_0_unscaled: 0.0527 (0.1538)  loss_giou_0_unscaled: 0.1085 (0.2411)  cardinality_error_0_unscaled: 3844.7500 (3818.9814)  loss_ce_1_unscaled: 1.4310 (1.2697)  loss_bbox_1_unscaled: 0.0502 (0.1433)  loss_giou_1_unscaled: 0.0972 (0.2260)  cardinality_error_1_unscaled: 3835.0000 (3787.7335)  loss_ce_enc_unscaled: 1.3517 (1.1795)  loss_bbox_enc_unscaled: 0.0711 (0.1809)  loss_giou_enc_unscaled: 0.1509 (0.2915)  cardinality_error_enc_unscaled: 3785.5000 (3618.8946)  time: 1.6117  data: 0.0159  max mem: 9121
# Epoch: [0]  [130/340]  eta: 0:05:54  lr: 0.000100  class_error: 78.02  loss: 7.8394 (9.8770)  loss_ce: 1.3746 (1.2770)  loss_bbox: 0.3045 (0.6906)  loss_giou: 0.2432 (0.4434)  loss_ce_0: 1.3908 (1.2526)  loss_bbox_0: 0.2798 (0.7311)  loss_giou_0: 0.2193 (0.4644)  loss_ce_1: 1.4310 (1.2800)  loss_bbox_1: 0.2913 (0.6843)  loss_giou_1: 0.2256 (0.4375)  loss_ce_enc: 1.3563 (1.1925)  loss_bbox_enc: 0.3435 (0.8615)  loss_giou_enc: 0.2933 (0.5620)  loss_ce_unscaled: 1.3746 (1.2770)  class_error_unscaled: 73.0769 (83.2351)  loss_bbox_unscaled: 0.0609 (0.1381)  loss_giou_unscaled: 0.1216 (0.2217)  cardinality_error_unscaled: 3693.0000 (3410.9179)  loss_ce_0_unscaled: 1.3908 (1.2526)  loss_bbox_0_unscaled: 0.0560 (0.1462)  loss_giou_0_unscaled: 0.1097 (0.2322)  cardinality_error_0_unscaled: 3846.5000 (3821.3187)  loss_ce_1_unscaled: 1.4310 (1.2800)  loss_bbox_1_unscaled: 0.0583 (0.1369)  loss_giou_1_unscaled: 0.1128 (0.2187)  cardinality_error_1_unscaled: 3771.5000 (3781.3053)  loss_ce_enc_unscaled: 1.3563 (1.1925)  loss_bbox_enc_unscaled: 0.0687 (0.1723)  loss_giou_enc_unscaled: 0.1467 (0.2810)  cardinality_error_enc_unscaled: 3794.2500 (3632.1985)  time: 1.6291  data: 0.0157  max mem: 9121
# Epoch: [0]  [140/340]  eta: 0:05:36  lr: 0.000100  class_error: 94.87  loss: 7.7609 (9.7293)  loss_ce: 1.3707 (1.2843)  loss_bbox: 0.3045 (0.6640)  loss_giou: 0.2504 (0.4305)  loss_ce_0: 1.4084 (1.2633)  loss_bbox_0: 0.2749 (0.6992)  loss_giou_0: 0.2286 (0.4487)  loss_ce_1: 1.4147 (1.2910)  loss_bbox_1: 0.2799 (0.6546)  loss_giou_1: 0.2349 (0.4232)  loss_ce_enc: 1.3754 (1.2055)  loss_bbox_enc: 0.3101 (0.8234)  loss_giou_enc: 0.2734 (0.5417)  loss_ce_unscaled: 1.3707 (1.2843)  class_error_unscaled: 73.0769 (82.9264)  loss_bbox_unscaled: 0.0609 (0.1328)  loss_giou_unscaled: 0.1252 (0.2152)  cardinality_error_unscaled: 3682.5000 (3430.6277)  loss_ce_0_unscaled: 1.4084 (1.2633)  loss_bbox_0_unscaled: 0.0550 (0.1398)  loss_giou_0_unscaled: 0.1143 (0.2244)  cardinality_error_0_unscaled: 3859.5000 (3825.2801)  loss_ce_1_unscaled: 1.4147 (1.2910)  loss_bbox_1_unscaled: 0.0560 (0.1309)  loss_giou_1_unscaled: 0.1175 (0.2116)  cardinality_error_1_unscaled: 3707.2500 (3776.2128)  loss_ce_enc_unscaled: 1.3754 (1.2055)  loss_bbox_enc_unscaled: 0.0620 (0.1647)  loss_giou_enc_unscaled: 0.1367 (0.2708)  cardinality_error_enc_unscaled: 3794.2500 (3644.9858)  time: 1.5892  data: 0.0156  max mem: 9121
# Epoch: [0]  [150/340]  eta: 0:05:19  lr: 0.000100  class_error: 83.08  loss: 7.6564 (9.5958)  loss_ce: 1.3335 (1.2857)  loss_bbox: 0.3353 (0.6424)  loss_giou: 0.2706 (0.4213)  loss_ce_0: 1.4084 (1.2722)  loss_bbox_0: 0.2567 (0.6709)  loss_giou_0: 0.2296 (0.4354)  loss_ce_1: 1.4191 (1.2985)  loss_bbox_1: 0.2574 (0.6295)  loss_giou_1: 0.2349 (0.4118)  loss_ce_enc: 1.3883 (1.2176)  loss_bbox_enc: 0.2940 (0.7875)  loss_giou_enc: 0.2550 (0.5230)  loss_ce_unscaled: 1.3335 (1.2857)  class_error_unscaled: 76.9231 (82.4550)  loss_bbox_unscaled: 0.0671 (0.1285)  loss_giou_unscaled: 0.1353 (0.2106)  cardinality_error_unscaled: 3571.5000 (3432.2235)  loss_ce_0_unscaled: 1.4084 (1.2722)  loss_bbox_0_unscaled: 0.0513 (0.1342)  loss_giou_0_unscaled: 0.1148 (0.2177)  cardinality_error_0_unscaled: 3880.7500 (3828.9437)  loss_ce_1_unscaled: 1.4191 (1.2985)  loss_bbox_1_unscaled: 0.0515 (0.1259)  loss_giou_1_unscaled: 0.1175 (0.2059)  cardinality_error_1_unscaled: 3658.0000 (3765.7334)  loss_ce_enc_unscaled: 1.3883 (1.2176)  loss_bbox_enc_unscaled: 0.0588 (0.1575)  loss_giou_enc_unscaled: 0.1275 (0.2615)  cardinality_error_enc_unscaled: 3827.2500 (3656.2831)  time: 1.6528  data: 0.0159  max mem: 9121
# Epoch: [0]  [160/340]  eta: 0:05:02  lr: 0.000100  class_error: 76.92  loss: 7.6979 (9.4997)  loss_ce: 1.3098 (1.2881)  loss_bbox: 0.3494 (0.6277)  loss_giou: 0.2863 (0.4143)  loss_ce_0: 1.4114 (1.2813)  loss_bbox_0: 0.2593 (0.6494)  loss_giou_0: 0.2467 (0.4248)  loss_ce_1: 1.4172 (1.3044)  loss_bbox_1: 0.2639 (0.6111)  loss_giou_1: 0.2451 (0.4028)  loss_ce_enc: 1.3983 (1.2280)  loss_bbox_enc: 0.2890 (0.7598)  loss_giou_enc: 0.2549 (0.5081)  loss_ce_unscaled: 1.3098 (1.2881)  class_error_unscaled: 76.9231 (81.9241)  loss_bbox_unscaled: 0.0699 (0.1255)  loss_giou_unscaled: 0.1431 (0.2072)  cardinality_error_unscaled: 3495.0000 (3438.5590)  loss_ce_0_unscaled: 1.4114 (1.2813)  loss_bbox_0_unscaled: 0.0519 (0.1299)  loss_giou_0_unscaled: 0.1233 (0.2124)  cardinality_error_0_unscaled: 3890.5000 (3832.8742)  loss_ce_1_unscaled: 1.4172 (1.3044)  loss_bbox_1_unscaled: 0.0528 (0.1222)  loss_giou_1_unscaled: 0.1226 (0.2014)  cardinality_error_1_unscaled: 3666.7500 (3761.8012)  loss_ce_enc_unscaled: 1.3983 (1.2280)  loss_bbox_enc_unscaled: 0.0578 (0.1520)  loss_giou_enc_unscaled: 0.1274 (0.2540)  cardinality_error_enc_unscaled: 3827.2500 (3667.4363)  time: 1.6628  data: 0.0154  max mem: 9121
# Epoch: [0]  [170/340]  eta: 0:04:46  lr: 0.000100  class_error: 79.12  loss: 7.7695 (9.3947)  loss_ce: 1.3035 (1.2868)  loss_bbox: 0.3688 (0.6113)  loss_giou: 0.3295 (0.4087)  loss_ce_0: 1.4147 (1.2884)  loss_bbox_0: 0.2513 (0.6257)  loss_giou_0: 0.2600 (0.4149)  loss_ce_1: 1.3738 (1.3066)  loss_bbox_1: 0.2639 (0.5918)  loss_giou_1: 0.2776 (0.3955)  loss_ce_enc: 1.3898 (1.2364)  loss_bbox_enc: 0.2988 (0.7326)  loss_giou_enc: 0.2666 (0.4959)  loss_ce_unscaled: 1.3035 (1.2868)  class_error_unscaled: 71.1538 (81.0849)  loss_bbox_unscaled: 0.0738 (0.1223)  loss_giou_unscaled: 0.1648 (0.2044)  cardinality_error_unscaled: 3347.5000 (3418.9620)  loss_ce_0_unscaled: 1.4147 (1.2884)  loss_bbox_0_unscaled: 0.0503 (0.1251)  loss_giou_0_unscaled: 0.1300 (0.2075)  cardinality_error_0_unscaled: 3889.2500 (3835.3772)  loss_ce_1_unscaled: 1.3738 (1.3066)  loss_bbox_1_unscaled: 0.0528 (0.1184)  loss_giou_1_unscaled: 0.1388 (0.1978)  cardinality_error_1_unscaled: 3554.7500 (3744.5892)  loss_ce_enc_unscaled: 1.3898 (1.2364)  loss_bbox_enc_unscaled: 0.0598 (0.1465)  loss_giou_enc_unscaled: 0.1333 (0.2480)  cardinality_error_enc_unscaled: 3826.7500 (3676.7968)  time: 1.6922  data: 0.0157  max mem: 9121
# Epoch: [0]  [180/340]  eta: 0:04:27  lr: 0.000100  class_error: 84.62  loss: 7.7695 (9.3093)  loss_ce: 1.2516 (1.2844)  loss_bbox: 0.3619 (0.5986)  loss_giou: 0.3295 (0.4046)  loss_ce_0: 1.3922 (1.2931)  loss_bbox_0: 0.2446 (0.6082)  loss_giou_0: 0.2614 (0.4079)  loss_ce_1: 1.3468 (1.3073)  loss_bbox_1: 0.2689 (0.5766)  loss_giou_1: 0.2915 (0.3901)  loss_ce_enc: 1.3771 (1.2440)  loss_bbox_enc: 0.2988 (0.7096)  loss_giou_enc: 0.2863 (0.4848)  loss_ce_unscaled: 1.2516 (1.2844)  class_error_unscaled: 69.2308 (80.8275)  loss_bbox_unscaled: 0.0724 (0.1197)  loss_giou_unscaled: 0.1648 (0.2023)  cardinality_error_unscaled: 2957.2500 (3388.3729)  loss_ce_0_unscaled: 1.3922 (1.2931)  loss_bbox_0_unscaled: 0.0489 (0.1216)  loss_giou_0_unscaled: 0.1307 (0.2040)  cardinality_error_0_unscaled: 3870.0000 (3836.1188)  loss_ce_1_unscaled: 1.3468 (1.3073)  loss_bbox_1_unscaled: 0.0538 (0.1153)  loss_giou_1_unscaled: 0.1457 (0.1951)  cardinality_error_1_unscaled: 3434.2500 (3727.0249)  loss_ce_enc_unscaled: 1.3771 (1.2440)  loss_bbox_enc_unscaled: 0.0598 (0.1419)  loss_giou_enc_unscaled: 0.1432 (0.2424)  cardinality_error_enc_unscaled: 3826.7500 (3685.1713)  time: 1.6141  data: 0.0162  max mem: 9121
# Epoch: [0]  [190/340]  eta: 0:04:11  lr: 0.000100  class_error: 43.08  loss: 7.8371 (9.2296)  loss_ce: 1.2749 (1.2848)  loss_bbox: 0.3692 (0.5860)  loss_giou: 0.3170 (0.3989)  loss_ce_0: 1.3922 (1.3000)  loss_bbox_0: 0.2700 (0.5903)  loss_giou_0: 0.2581 (0.3987)  loss_ce_1: 1.3468 (1.3105)  loss_bbox_1: 0.3029 (0.5626)  loss_giou_1: 0.2778 (0.3832)  loss_ce_enc: 1.3852 (1.2525)  loss_bbox_enc: 0.2964 (0.6888)  loss_giou_enc: 0.2777 (0.4732)  loss_ce_unscaled: 1.2749 (1.2848)  class_error_unscaled: 73.0769 (80.2283)  loss_bbox_unscaled: 0.0738 (0.1172)  loss_giou_unscaled: 0.1585 (0.1995)  cardinality_error_unscaled: 2749.2500 (3346.6479)  loss_ce_0_unscaled: 1.3922 (1.3000)  loss_bbox_0_unscaled: 0.0540 (0.1181)  loss_giou_0_unscaled: 0.1290 (0.1993)  cardinality_error_0_unscaled: 3842.0000 (3835.7971)  loss_ce_1_unscaled: 1.3468 (1.3105)  loss_bbox_1_unscaled: 0.0606 (0.1125)  loss_giou_1_unscaled: 0.1389 (0.1916)  cardinality_error_1_unscaled: 3400.0000 (3710.7186)  loss_ce_enc_unscaled: 1.3852 (1.2525)  loss_bbox_enc_unscaled: 0.0593 (0.1378)  loss_giou_enc_unscaled: 0.1389 (0.2366)  cardinality_error_enc_unscaled: 3823.7500 (3690.3024)  time: 1.5988  data: 0.0154  max mem: 9121
# Epoch: [0]  [200/340]  eta: 0:03:55  lr: 0.000100  class_error: 73.08  loss: 7.7871 (9.1537)  loss_ce: 1.2913 (1.2857)  loss_bbox: 0.3586 (0.5742)  loss_giou: 0.2753 (0.3933)  loss_ce_0: 1.4152 (1.3049)  loss_bbox_0: 0.2622 (0.5737)  loss_giou_0: 0.2243 (0.3903)  loss_ce_1: 1.3567 (1.3141)  loss_bbox_1: 0.2961 (0.5488)  loss_giou_1: 0.2513 (0.3766)  loss_ce_enc: 1.4169 (1.2611)  loss_bbox_enc: 0.2744 (0.6689)  loss_giou_enc: 0.2425 (0.4620)  loss_ce_unscaled: 1.2913 (1.2857)  class_error_unscaled: 73.0769 (79.7540)  loss_bbox_unscaled: 0.0717 (0.1148)  loss_giou_unscaled: 0.1377 (0.1967)  cardinality_error_unscaled: 2352.7500 (3295.2276)  loss_ce_0_unscaled: 1.4152 (1.3049)  loss_bbox_0_unscaled: 0.0524 (0.1147)  loss_giou_0_unscaled: 0.1121 (0.1951)  cardinality_error_0_unscaled: 3788.0000 (3826.5622)  loss_ce_1_unscaled: 1.3567 (1.3141)  loss_bbox_1_unscaled: 0.0592 (0.1098)  loss_giou_1_unscaled: 0.1256 (0.1883)  cardinality_error_1_unscaled: 3269.5000 (3683.1219)  loss_ce_enc_unscaled: 1.4169 (1.2611)  loss_bbox_enc_unscaled: 0.0549 (0.1338)  loss_giou_enc_unscaled: 0.1213 (0.2310)  cardinality_error_enc_unscaled: 3749.2500 (3692.6940)  time: 1.7419  data: 0.0154  max mem: 9121
# Epoch: [0]  [210/340]  eta: 0:03:37  lr: 0.000100  class_error: 75.38  loss: 7.6926 (9.0879)  loss_ce: 1.2801 (1.2855)  loss_bbox: 0.3495 (0.5644)  loss_giou: 0.2597 (0.3878)  loss_ce_0: 1.4171 (1.3109)  loss_bbox_0: 0.2377 (0.5595)  loss_giou_0: 0.2185 (0.3826)  loss_ce_1: 1.3640 (1.3167)  loss_bbox_1: 0.2833 (0.5373)  loss_giou_1: 0.2361 (0.3706)  loss_ce_enc: 1.4249 (1.2693)  loss_bbox_enc: 0.2718 (0.6515)  loss_giou_enc: 0.2397 (0.4519)  loss_ce_unscaled: 1.2801 (1.2855)  class_error_unscaled: 62.3932 (78.8182)  loss_bbox_unscaled: 0.0699 (0.1129)  loss_giou_unscaled: 0.1299 (0.1939)  cardinality_error_unscaled: 2453.0000 (3273.5367)  loss_ce_0_unscaled: 1.4171 (1.3109)  loss_bbox_0_unscaled: 0.0475 (0.1119)  loss_giou_0_unscaled: 0.1093 (0.1913)  cardinality_error_0_unscaled: 3693.5000 (3821.6943)  loss_ce_1_unscaled: 1.3640 (1.3167)  loss_bbox_1_unscaled: 0.0567 (0.1075)  loss_giou_1_unscaled: 0.1181 (0.1853)  cardinality_error_1_unscaled: 3357.2500 (3673.4585)  loss_ce_enc_unscaled: 1.4249 (1.2693)  loss_bbox_enc_unscaled: 0.0544 (0.1303)  loss_giou_enc_unscaled: 0.1198 (0.2259)  cardinality_error_enc_unscaled: 3749.5000 (3695.4692)  time: 1.6350  data: 0.0154  max mem: 9121
# Epoch: [0]  [220/340]  eta: 0:03:20  lr: 0.000100  class_error: 73.08  loss: 7.6402 (9.0290)  loss_ce: 1.2444 (1.2836)  loss_bbox: 0.3604 (0.5570)  loss_giou: 0.2778 (0.3857)  loss_ce_0: 1.4105 (1.3153)  loss_bbox_0: 0.2501 (0.5458)  loss_giou_0: 0.2263 (0.3761)  loss_ce_1: 1.3450 (1.3171)  loss_bbox_1: 0.2903 (0.5269)  loss_giou_1: 0.2465 (0.3665)  loss_ce_enc: 1.4249 (1.2755)  loss_bbox_enc: 0.2718 (0.6354)  loss_giou_enc: 0.2631 (0.4441)  loss_ce_unscaled: 1.2444 (1.2836)  class_error_unscaled: 62.3932 (78.2846)  loss_bbox_unscaled: 0.0721 (0.1114)  loss_giou_unscaled: 0.1389 (0.1928)  cardinality_error_unscaled: 2644.0000 (3227.9910)  loss_ce_0_unscaled: 1.4105 (1.3153)  loss_bbox_0_unscaled: 0.0500 (0.1092)  loss_giou_0_unscaled: 0.1132 (0.1881)  cardinality_error_0_unscaled: 3716.5000 (3816.0973)  loss_ce_1_unscaled: 1.3450 (1.3171)  loss_bbox_1_unscaled: 0.0581 (0.1054)  loss_giou_1_unscaled: 0.1233 (0.1832)  cardinality_error_1_unscaled: 3410.0000 (3648.5170)  loss_ce_enc_unscaled: 1.4249 (1.2755)  loss_bbox_enc_unscaled: 0.0544 (0.1271)  loss_giou_enc_unscaled: 0.1316 (0.2220)  cardinality_error_enc_unscaled: 3750.7500 (3696.1878)  time: 1.5936  data: 0.0149  max mem: 9121
# Epoch: [0]  [230/340]  eta: 0:03:03  lr: 0.000100  class_error: 51.05  loss: 7.7644 (8.9741)  loss_ce: 1.2444 (1.2836)  loss_bbox: 0.3628 (0.5485)  loss_giou: 0.3050 (0.3818)  loss_ce_0: 1.4033 (1.3201)  loss_bbox_0: 0.2501 (0.5332)  loss_giou_0: 0.2390 (0.3700)  loss_ce_1: 1.3237 (1.3189)  loss_bbox_1: 0.2923 (0.5171)  loss_giou_1: 0.2776 (0.3619)  loss_ce_enc: 1.3966 (1.2818)  loss_bbox_enc: 0.2875 (0.6208)  loss_giou_enc: 0.2711 (0.4364)  loss_ce_unscaled: 1.2444 (1.2836)  class_error_unscaled: 63.2479 (77.7750)  loss_bbox_unscaled: 0.0726 (0.1097)  loss_giou_unscaled: 0.1525 (0.1909)  cardinality_error_unscaled: 1856.5000 (3158.6797)  loss_ce_0_unscaled: 1.4033 (1.3201)  loss_bbox_0_unscaled: 0.0500 (0.1066)  loss_giou_0_unscaled: 0.1195 (0.1850)  cardinality_error_0_unscaled: 3531.0000 (3796.4870)  loss_ce_1_unscaled: 1.3237 (1.3189)  loss_bbox_1_unscaled: 0.0585 (0.1034)  loss_giou_1_unscaled: 0.1388 (0.1809)  cardinality_error_1_unscaled: 2833.2500 (3605.1515)  loss_ce_enc_unscaled: 1.3966 (1.2818)  loss_bbox_enc_unscaled: 0.0575 (0.1242)  loss_giou_enc_unscaled: 0.1355 (0.2182)  cardinality_error_enc_unscaled: 3508.2500 (3675.8734)  time: 1.6807  data: 0.0160  max mem: 9121
# Epoch: [0]  [240/340]  eta: 0:02:46  lr: 0.000100  class_error: 63.46  loss: 7.7754 (8.9302)  loss_ce: 1.2775 (1.2836)  loss_bbox: 0.3764 (0.5425)  loss_giou: 0.2956 (0.3784)  loss_ce_0: 1.4209 (1.3251)  loss_bbox_0: 0.2454 (0.5223)  loss_giou_0: 0.2423 (0.3641)  loss_ce_1: 1.3681 (1.3213)  loss_bbox_1: 0.2962 (0.5094)  loss_giou_1: 0.2577 (0.3576)  loss_ce_enc: 1.4224 (1.2885)  loss_bbox_enc: 0.2878 (0.6083)  loss_giou_enc: 0.2705 (0.4290)  loss_ce_unscaled: 1.2775 (1.2836)  class_error_unscaled: 60.2564 (76.9850)  loss_bbox_unscaled: 0.0753 (0.1085)  loss_giou_unscaled: 0.1478 (0.1892)  cardinality_error_unscaled: 2351.5000 (3162.3071)  loss_ce_0_unscaled: 1.4209 (1.3251)  loss_bbox_0_unscaled: 0.0491 (0.1045)  loss_giou_0_unscaled: 0.1212 (0.1821)  cardinality_error_0_unscaled: 3413.2500 (3781.4232)  loss_ce_1_unscaled: 1.3681 (1.3213)  loss_bbox_1_unscaled: 0.0592 (0.1019)  loss_giou_1_unscaled: 0.1289 (0.1788)  cardinality_error_1_unscaled: 2912.7500 (3591.2718)  loss_ce_enc_unscaled: 1.4224 (1.2885)  loss_bbox_enc_unscaled: 0.0576 (0.1217)  loss_giou_enc_unscaled: 0.1352 (0.2145)  cardinality_error_enc_unscaled: 3190.7500 (3655.1141)  time: 1.6201  data: 0.0158  max mem: 9121
# Epoch: [0]  [250/340]  eta: 0:02:29  lr: 0.000100  class_error: 96.70  loss: 7.7754 (8.8801)  loss_ce: 1.2630 (1.2828)  loss_bbox: 0.3899 (0.5357)  loss_giou: 0.2893 (0.3753)  loss_ce_0: 1.4279 (1.3287)  loss_bbox_0: 0.2478 (0.5111)  loss_giou_0: 0.2075 (0.3590)  loss_ce_1: 1.3493 (1.3217)  loss_bbox_1: 0.2984 (0.5007)  loss_giou_1: 0.2460 (0.3537)  loss_ce_enc: 1.4354 (1.2938)  loss_bbox_enc: 0.2825 (0.5952)  loss_giou_enc: 0.2546 (0.4224)  loss_ce_unscaled: 1.2630 (1.2828)  class_error_unscaled: 63.4615 (76.7336)  loss_bbox_unscaled: 0.0780 (0.1071)  loss_giou_unscaled: 0.1447 (0.1876)  cardinality_error_unscaled: 2932.7500 (3146.7689)  loss_ce_0_unscaled: 1.4279 (1.3287)  loss_bbox_0_unscaled: 0.0496 (0.1022)  loss_giou_0_unscaled: 0.1037 (0.1795)  cardinality_error_0_unscaled: 3379.2500 (3762.5677)  loss_ce_1_unscaled: 1.3493 (1.3217)  loss_bbox_1_unscaled: 0.0597 (0.1001)  loss_giou_1_unscaled: 0.1230 (0.1769)  cardinality_error_1_unscaled: 3108.7500 (3565.1813)  loss_ce_enc_unscaled: 1.4354 (1.2938)  loss_bbox_enc_unscaled: 0.0565 (0.1190)  loss_giou_enc_unscaled: 0.1273 (0.2112)  cardinality_error_enc_unscaled: 3162.7500 (3633.5090)  time: 1.4960  data: 0.0161  max mem: 9121
# Epoch: [0]  [260/340]  eta: 0:02:13  lr: 0.000100  class_error: 64.62  loss: 7.6236 (8.8311)  loss_ce: 1.2565 (1.2820)  loss_bbox: 0.3588 (0.5290)  loss_giou: 0.2506 (0.3710)  loss_ce_0: 1.4118 (1.3325)  loss_bbox_0: 0.2418 (0.5008)  loss_giou_0: 0.2026 (0.3529)  loss_ce_1: 1.3255 (1.3226)  loss_bbox_1: 0.3027 (0.4930)  loss_giou_1: 0.2269 (0.3491)  loss_ce_enc: 1.4538 (1.2996)  loss_bbox_enc: 0.2716 (0.5834)  loss_giou_enc: 0.2328 (0.4152)  loss_ce_unscaled: 1.2565 (1.2820)  class_error_unscaled: 66.1538 (76.3802)  loss_bbox_unscaled: 0.0718 (0.1058)  loss_giou_unscaled: 0.1253 (0.1855)  cardinality_error_unscaled: 2859.7500 (3134.8573)  loss_ce_0_unscaled: 1.4118 (1.3325)  loss_bbox_0_unscaled: 0.0484 (0.1002)  loss_giou_0_unscaled: 0.1013 (0.1765)  cardinality_error_0_unscaled: 3299.7500 (3745.0776)  loss_ce_1_unscaled: 1.3255 (1.3226)  loss_bbox_1_unscaled: 0.0605 (0.0986)  loss_giou_1_unscaled: 0.1135 (0.1746)  cardinality_error_1_unscaled: 2939.5000 (3543.4875)  loss_ce_enc_unscaled: 1.4538 (1.2996)  loss_bbox_enc_unscaled: 0.0543 (0.1167)  loss_giou_enc_unscaled: 0.1164 (0.2076)  cardinality_error_enc_unscaled: 3083.5000 (3612.2989)  time: 1.6150  data: 0.0168  max mem: 9121
# Epoch: [0]  [270/340]  eta: 0:01:56  lr: 0.000100  class_error: 64.10  loss: 7.5662 (8.7841)  loss_ce: 1.2249 (1.2792)  loss_bbox: 0.3407 (0.5222)  loss_giou: 0.2914 (0.3690)  loss_ce_0: 1.3954 (1.3346)  loss_bbox_0: 0.2385 (0.4912)  loss_giou_0: 0.2215 (0.3492)  loss_ce_1: 1.3179 (1.3208)  loss_bbox_1: 0.3027 (0.4860)  loss_giou_1: 0.2668 (0.3469)  loss_ce_enc: 1.4393 (1.3041)  loss_bbox_enc: 0.2690 (0.5713)  loss_giou_enc: 0.2435 (0.4096)  loss_ce_unscaled: 1.2249 (1.2792)  class_error_unscaled: 64.6154 (75.8708)  loss_bbox_unscaled: 0.0681 (0.1044)  loss_giou_unscaled: 0.1457 (0.1845)  cardinality_error_unscaled: 3071.0000 (3137.2297)  loss_ce_0_unscaled: 1.3954 (1.3346)  loss_bbox_0_unscaled: 0.0477 (0.0982)  loss_giou_0_unscaled: 0.1107 (0.1746)  cardinality_error_0_unscaled: 3263.7500 (3723.1734)  loss_ce_1_unscaled: 1.3179 (1.3208)  loss_bbox_1_unscaled: 0.0605 (0.0972)  loss_giou_1_unscaled: 0.1334 (0.1735)  cardinality_error_1_unscaled: 2987.7500 (3521.9788)  loss_ce_enc_unscaled: 1.4393 (1.3041)  loss_bbox_enc_unscaled: 0.0538 (0.1143)  loss_giou_enc_unscaled: 0.1217 (0.2048)  cardinality_error_enc_unscaled: 3059.7500 (3591.0867)  time: 1.7884  data: 0.0160  max mem: 9121
# Epoch: [0]  [280/340]  eta: 0:01:40  lr: 0.000100  class_error: 80.00  loss: 7.5420 (8.7483)  loss_ce: 1.1707 (1.2743)  loss_bbox: 0.3585 (0.5179)  loss_giou: 0.3246 (0.3688)  loss_ce_0: 1.3942 (1.3366)  loss_bbox_0: 0.2469 (0.4837)  loss_giou_0: 0.2424 (0.3471)  loss_ce_1: 1.2529 (1.3182)  loss_bbox_1: 0.3149 (0.4809)  loss_giou_1: 0.2890 (0.3464)  loss_ce_enc: 1.4254 (1.3076)  loss_bbox_enc: 0.2613 (0.5613)  loss_giou_enc: 0.2517 (0.4056)  loss_ce_unscaled: 1.1707 (1.2743)  class_error_unscaled: 61.5385 (75.4384)  loss_bbox_unscaled: 0.0717 (0.1036)  loss_giou_unscaled: 0.1623 (0.1844)  cardinality_error_unscaled: 3123.0000 (3136.1495)  loss_ce_0_unscaled: 1.3942 (1.3366)  loss_bbox_0_unscaled: 0.0494 (0.0967)  loss_giou_0_unscaled: 0.1212 (0.1735)  cardinality_error_0_unscaled: 3263.7500 (3711.0916)  loss_ce_1_unscaled: 1.2529 (1.3182)  loss_bbox_1_unscaled: 0.0630 (0.0962)  loss_giou_1_unscaled: 0.1445 (0.1732)  cardinality_error_1_unscaled: 3133.5000 (3512.8043)  loss_ce_enc_unscaled: 1.4254 (1.3076)  loss_bbox_enc_unscaled: 0.0523 (0.1123)  loss_giou_enc_unscaled: 0.1259 (0.2028)  cardinality_error_enc_unscaled: 3090.7500 (3574.5560)  time: 1.7876  data: 0.0160  max mem: 9121
# Epoch: [0]  [290/340]  eta: 0:01:23  lr: 0.000100  class_error: 50.00  loss: 7.5713 (8.7067)  loss_ce: 1.1263 (1.2697)  loss_bbox: 0.3739 (0.5145)  loss_giou: 0.3118 (0.3670)  loss_ce_0: 1.3942 (1.3389)  loss_bbox_0: 0.2433 (0.4755)  loss_giou_0: 0.2238 (0.3428)  loss_ce_1: 1.2373 (1.3153)  loss_bbox_1: 0.3192 (0.4760)  loss_giou_1: 0.2817 (0.3440)  loss_ce_enc: 1.4396 (1.3127)  loss_bbox_enc: 0.2555 (0.5506)  loss_giou_enc: 0.2370 (0.3997)  loss_ce_unscaled: 1.1263 (1.2697)  class_error_unscaled: 62.8205 (74.8741)  loss_bbox_unscaled: 0.0748 (0.1029)  loss_giou_unscaled: 0.1559 (0.1835)  cardinality_error_unscaled: 2849.5000 (3116.9820)  loss_ce_0_unscaled: 1.3942 (1.3389)  loss_bbox_0_unscaled: 0.0487 (0.0951)  loss_giou_0_unscaled: 0.1119 (0.1714)  cardinality_error_0_unscaled: 3512.0000 (3705.4863)  loss_ce_1_unscaled: 1.2373 (1.3153)  loss_bbox_1_unscaled: 0.0638 (0.0952)  loss_giou_1_unscaled: 0.1409 (0.1720)  cardinality_error_1_unscaled: 2991.2500 (3489.0404)  loss_ce_enc_unscaled: 1.4396 (1.3127)  loss_bbox_enc_unscaled: 0.0511 (0.1101)  loss_giou_enc_unscaled: 0.1185 (0.1998)  cardinality_error_enc_unscaled: 3179.5000 (3563.1598)  time: 1.6993  data: 0.0160  max mem: 9121
# Epoch: [0]  [300/340]  eta: 0:01:06  lr: 0.000100  class_error: 61.54  loss: 7.4461 (8.6669)  loss_ce: 1.1605 (1.2668)  loss_bbox: 0.3733 (0.5107)  loss_giou: 0.2932 (0.3634)  loss_ce_0: 1.4019 (1.3411)  loss_bbox_0: 0.2379 (0.4681)  loss_giou_0: 0.2093 (0.3379)  loss_ce_1: 1.2373 (1.3135)  loss_bbox_1: 0.2978 (0.4714)  loss_giou_1: 0.2548 (0.3402)  loss_ce_enc: 1.4564 (1.3182)  loss_bbox_enc: 0.2496 (0.5420)  loss_giou_enc: 0.2209 (0.3937)  loss_ce_unscaled: 1.1605 (1.2668)  class_error_unscaled: 64.6154 (74.7224)  loss_bbox_unscaled: 0.0747 (0.1021)  loss_giou_unscaled: 0.1466 (0.1817)  cardinality_error_unscaled: 2698.2500 (3107.9668)  loss_ce_0_unscaled: 1.4019 (1.3411)  loss_bbox_0_unscaled: 0.0476 (0.0936)  loss_giou_0_unscaled: 0.1046 (0.1689)  cardinality_error_0_unscaled: 3557.5000 (3696.7699)  loss_ce_1_unscaled: 1.2373 (1.3135)  loss_bbox_1_unscaled: 0.0596 (0.0943)  loss_giou_1_unscaled: 0.1274 (0.1701)  cardinality_error_1_unscaled: 2838.0000 (3472.3198)  loss_ce_enc_unscaled: 1.4564 (1.3182)  loss_bbox_enc_unscaled: 0.0499 (0.1084)  loss_giou_enc_unscaled: 0.1105 (0.1969)  cardinality_error_enc_unscaled: 3230.0000 (3552.9319)  time: 1.6184  data: 0.0157  max mem: 9121
# Epoch: [0]  [310/340]  eta: 0:00:50  lr: 0.000100  class_error: 35.90  loss: 7.4884 (8.6295)  loss_ce: 1.1636 (1.2637)  loss_bbox: 0.3733 (0.5062)  loss_giou: 0.2777 (0.3617)  loss_ce_0: 1.3880 (1.3428)  loss_bbox_0: 0.2260 (0.4609)  loss_giou_0: 0.2132 (0.3345)  loss_ce_1: 1.2567 (1.3112)  loss_bbox_1: 0.3140 (0.4666)  loss_giou_1: 0.2579 (0.3383)  loss_ce_enc: 1.4528 (1.3216)  loss_bbox_enc: 0.2610 (0.5330)  loss_giou_enc: 0.2286 (0.3890)  loss_ce_unscaled: 1.1636 (1.2637)  class_error_unscaled: 70.9402 (74.6125)  loss_bbox_unscaled: 0.0747 (0.1012)  loss_giou_unscaled: 0.1389 (0.1808)  cardinality_error_unscaled: 3179.7500 (3117.1045)  loss_ce_0_unscaled: 1.3880 (1.3428)  loss_bbox_0_unscaled: 0.0452 (0.0922)  loss_giou_0_unscaled: 0.1066 (0.1673)  cardinality_error_0_unscaled: 3526.2500 (3693.7170)  loss_ce_1_unscaled: 1.2567 (1.3112)  loss_bbox_1_unscaled: 0.0628 (0.0933)  loss_giou_1_unscaled: 0.1290 (0.1692)  cardinality_error_1_unscaled: 3231.7500 (3467.4180)  loss_ce_enc_unscaled: 1.4528 (1.3216)  loss_bbox_enc_unscaled: 0.0522 (0.1066)  loss_giou_enc_unscaled: 0.1143 (0.1945)  cardinality_error_enc_unscaled: 3363.7500 (3550.5740)  time: 1.6604  data: 0.0155  max mem: 9121
# Epoch: [0]  [320/340]  eta: 0:00:33  lr: 0.000100  class_error: 56.92  loss: 7.6601 (8.6054)  loss_ce: 1.1725 (1.2608)  loss_bbox: 0.3963 (0.5045)  loss_giou: 0.3093 (0.3610)  loss_ce_0: 1.3974 (1.3455)  loss_bbox_0: 0.2418 (0.4554)  loss_giou_0: 0.2227 (0.3320)  loss_ce_1: 1.2252 (1.3087)  loss_bbox_1: 0.3450 (0.4642)  loss_giou_1: 0.2770 (0.3376)  loss_ce_enc: 1.4216 (1.3252)  loss_bbox_enc: 0.2692 (0.5256)  loss_giou_enc: 0.2286 (0.3849)  loss_ce_unscaled: 1.1725 (1.2608)  class_error_unscaled: 70.7692 (74.4314)  loss_bbox_unscaled: 0.0793 (0.1009)  loss_giou_unscaled: 0.1546 (0.1805)  cardinality_error_unscaled: 3258.2500 (3121.1488)  loss_ce_0_unscaled: 1.3974 (1.3455)  loss_bbox_0_unscaled: 0.0484 (0.0911)  loss_giou_0_unscaled: 0.1114 (0.1660)  cardinality_error_0_unscaled: 3663.0000 (3693.8637)  loss_ce_1_unscaled: 1.2252 (1.3087)  loss_bbox_1_unscaled: 0.0690 (0.0928)  loss_giou_1_unscaled: 0.1385 (0.1688)  cardinality_error_1_unscaled: 3345.0000 (3463.4229)  loss_ce_enc_unscaled: 1.4216 (1.3252)  loss_bbox_enc_unscaled: 0.0538 (0.1051)  loss_giou_enc_unscaled: 0.1143 (0.1925)  cardinality_error_enc_unscaled: 3534.2500 (3551.5530)  time: 1.6254  data: 0.0152  max mem: 9121
# Epoch: [0]  [330/340]  eta: 0:00:16  lr: 0.000100  class_error: 64.10  loss: 7.7014 (8.5770)  loss_ce: 1.1654 (1.2583)  loss_bbox: 0.3963 (0.5013)  loss_giou: 0.3189 (0.3598)  loss_ce_0: 1.4119 (1.3473)  loss_bbox_0: 0.2584 (0.4494)  loss_giou_0: 0.2227 (0.3292)  loss_ce_1: 1.2044 (1.3057)  loss_bbox_1: 0.3623 (0.4614)  loss_giou_1: 0.3041 (0.3367)  loss_ce_enc: 1.4579 (1.3289)  loss_bbox_enc: 0.2734 (0.5180)  loss_giou_enc: 0.2426 (0.3810)  loss_ce_unscaled: 1.1654 (1.2583)  class_error_unscaled: 64.1026 (73.9977)  loss_bbox_unscaled: 0.0793 (0.1003)  loss_giou_unscaled: 0.1594 (0.1799)  cardinality_error_unscaled: 2973.7500 (3105.2462)  loss_ce_0_unscaled: 1.4119 (1.3473)  loss_bbox_0_unscaled: 0.0517 (0.0899)  loss_giou_0_unscaled: 0.1114 (0.1646)  cardinality_error_0_unscaled: 3553.0000 (3682.4924)  loss_ce_1_unscaled: 1.2044 (1.3057)  loss_bbox_1_unscaled: 0.0725 (0.0923)  loss_giou_1_unscaled: 0.1521 (0.1683)  cardinality_error_1_unscaled: 2861.2500 (3439.4841)  loss_ce_enc_unscaled: 1.4579 (1.3289)  loss_bbox_enc_unscaled: 0.0547 (0.1036)  loss_giou_enc_unscaled: 0.1213 (0.1905)  cardinality_error_enc_unscaled: 3455.0000 (3544.6813)  time: 1.6403  data: 0.0148  max mem: 9121
# Epoch: [0]  [339/340]  eta: 0:00:01  lr: 0.000100  class_error: 66.15  loss: 7.6475 (8.5577)  loss_ce: 1.1307 (1.2544)  loss_bbox: 0.4241 (0.5009)  loss_giou: 0.3249 (0.3602)  loss_ce_0: 1.4009 (1.3481)  loss_bbox_0: 0.2584 (0.4453)  loss_giou_0: 0.2374 (0.3277)  loss_ce_1: 1.1820 (1.3023)  loss_bbox_1: 0.3857 (0.4604)  loss_giou_1: 0.3060 (0.3369)  loss_ce_enc: 1.4300 (1.3312)  loss_bbox_enc: 0.2692 (0.5121)  loss_giou_enc: 0.2609 (0.3783)  loss_ce_unscaled: 1.1307 (1.2544)  class_error_unscaled: 64.1026 (73.8413)  loss_bbox_unscaled: 0.0848 (0.1002)  loss_giou_unscaled: 0.1624 (0.1801)  cardinality_error_unscaled: 3060.2500 (3115.5566)  loss_ce_0_unscaled: 1.4009 (1.3481)  loss_bbox_0_unscaled: 0.0517 (0.0891)  loss_giou_0_unscaled: 0.1187 (0.1639)  cardinality_error_0_unscaled: 3245.5000 (3668.0294)  loss_ce_1_unscaled: 1.1820 (1.3023)  loss_bbox_1_unscaled: 0.0771 (0.0921)  loss_giou_1_unscaled: 0.1530 (0.1684)  cardinality_error_1_unscaled: 2767.5000 (3428.5566)  loss_ce_enc_unscaled: 1.4300 (1.3312)  loss_bbox_enc_unscaled: 0.0538 (0.1024)  loss_giou_enc_unscaled: 0.1305 (0.1892)  cardinality_error_enc_unscaled: 3202.7500 (3529.3184)  time: 1.6795  data: 0.0145  max mem: 9121
# Epoch: [0] Total time: 0:09:27 (1.6679 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.15  loss: 7.6475 (8.5577)  loss_ce: 1.1307 (1.2544)  loss_bbox: 0.4241 (0.5009)  loss_giou: 0.3249 (0.3602)  loss_ce_0: 1.4009 (1.3481)  loss_bbox_0: 0.2584 (0.4453)  loss_giou_0: 0.2374 (0.3277)  loss_ce_1: 1.1820 (1.3023)  loss_bbox_1: 0.3857 (0.4604)  loss_giou_1: 0.3060 (0.3369)  loss_ce_enc: 1.4300 (1.3312)  loss_bbox_enc: 0.2692 (0.5121)  loss_giou_enc: 0.2609 (0.3783)  loss_ce_unscaled: 1.1307 (1.2544)  class_error_unscaled: 64.1026 (73.8413)  loss_bbox_unscaled: 0.0848 (0.1002)  loss_giou_unscaled: 0.1624 (0.1801)  cardinality_error_unscaled: 3060.2500 (3115.5566)  loss_ce_0_unscaled: 1.4009 (1.3481)  loss_bbox_0_unscaled: 0.0517 (0.0891)  loss_giou_0_unscaled: 0.1187 (0.1639)  cardinality_error_0_unscaled: 3245.5000 (3668.0294)  loss_ce_1_unscaled: 1.1820 (1.3023)  loss_bbox_1_unscaled: 0.0771 (0.0921)  loss_giou_1_unscaled: 0.1530 (0.1684)  cardinality_error_1_unscaled: 2767.5000 (3428.5566)  loss_ce_enc_unscaled: 1.4300 (1.3312)  loss_bbox_enc_unscaled: 0.0538 (0.1024)  loss_giou_enc_unscaled: 0.1305 (0.1892)  cardinality_error_enc_unscaled: 3202.7500 (3529.3184)
# Test:  [ 0/98]  eta: 0:01:09  class_error: 66.67  loss: 7.2022 (7.2022)  loss_ce: 1.0781 (1.0781)  loss_bbox: 0.3876 (0.3876)  loss_giou: 0.3272 (0.3272)  loss_ce_0: 1.3750 (1.3750)  loss_bbox_0: 0.2271 (0.2271)  loss_giou_0: 0.2174 (0.2174)  loss_ce_1: 1.1797 (1.1797)  loss_bbox_1: 0.2764 (0.2764)  loss_giou_1: 0.2570 (0.2570)  loss_ce_enc: 1.3828 (1.3828)  loss_bbox_enc: 0.2405 (0.2405)  loss_giou_enc: 0.2535 (0.2535)  loss_ce_unscaled: 1.0781 (1.0781)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.0775 (0.0775)  loss_giou_unscaled: 0.1636 (0.1636)  cardinality_error_unscaled: 292.7500 (292.7500)  loss_ce_0_unscaled: 1.3750 (1.3750)  loss_bbox_0_unscaled: 0.0454 (0.0454)  loss_giou_0_unscaled: 0.1087 (0.1087)  cardinality_error_0_unscaled: 266.7500 (266.7500)  loss_ce_1_unscaled: 1.1797 (1.1797)  loss_bbox_1_unscaled: 0.0553 (0.0553)  loss_giou_1_unscaled: 0.1285 (0.1285)  cardinality_error_1_unscaled: 260.5000 (260.5000)  loss_ce_enc_unscaled: 1.3828 (1.3828)  loss_bbox_enc_unscaled: 0.0481 (0.0481)  loss_giou_enc_unscaled: 0.1267 (0.1267)  cardinality_error_enc_unscaled: 200.7500 (200.7500)  time: 0.7085  data: 0.3644  max mem: 9121
# ...
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.199
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.303
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.162
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.515
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.762
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.784
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.642
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.787
# Test:  [ 0/98]  eta: 0:01:23  class_error: 50.00  loss: 6.9655 (6.9655)  loss_ce: 1.0547 (1.0547)  loss_bbox: 0.3529 (0.3529)  loss_giou: 0.2902 (0.2902)  loss_ce_0: 1.3516 (1.3516)  loss_bbox_0: 0.2053 (0.2053)  loss_giou_0: 0.1877 (0.1877)  loss_ce_1: 1.1250 (1.1250)  loss_bbox_1: 0.3231 (0.3231)  loss_giou_1: 0.2748 (0.2748)  loss_ce_enc: 1.4141 (1.4141)  loss_bbox_enc: 0.1909 (0.1909)  loss_giou_enc: 0.1953 (0.1953)  loss_ce_unscaled: 1.0547 (1.0547)  class_error_unscaled: 50.0000 (50.0000)  loss_bbox_unscaled: 0.0706 (0.0706)  loss_giou_unscaled: 0.1451 (0.1451)  cardinality_error_unscaled: 257.2500 (257.2500)  loss_ce_0_unscaled: 1.3516 (1.3516)  loss_bbox_0_unscaled: 0.0411 (0.0411)  loss_giou_0_unscaled: 0.0939 (0.0939)  cardinality_error_0_unscaled: 260.7500 (260.7500)  loss_ce_1_unscaled: 1.1250 (1.1250)  loss_bbox_1_unscaled: 0.0646 (0.0646)  loss_giou_1_unscaled: 0.1374 (0.1374)  cardinality_error_1_unscaled: 233.0000 (233.0000)  loss_ce_enc_unscaled: 1.4141 (1.4141)  loss_bbox_enc_unscaled: 0.0382 (0.0382)  loss_giou_enc_unscaled: 0.0976 (0.0976)  cardinality_error_enc_unscaled: 217.7500 (217.7500)  time: 0.8564  data: 0.4524  max mem: 9121
# Test:  [10/98]  eta: 0:00:30  class_error: 33.33  loss: 7.3059 (7.4571)  loss_ce: 1.1406 (1.1428)  loss_bbox: 0.3606 (0.3916)  loss_giou: 0.2824 (0.3165)  loss_ce_0: 1.3984 (1.4048)  loss_bbox_0: 0.2477 (0.2405)  loss_giou_0: 0.2163 (0.2311)  loss_ce_1: 1.1797 (1.1974)  loss_bbox_1: 0.3485 (0.3432)  loss_giou_1: 0.2789 (0.2916)  loss_ce_enc: 1.4609 (1.4496)  loss_bbox_enc: 0.1994 (0.2256)  loss_giou_enc: 0.2100 (0.2224)  loss_ce_unscaled: 1.1406 (1.1428)  class_error_unscaled: 60.0000 (66.0354)  loss_bbox_unscaled: 0.0721 (0.0783)  loss_giou_unscaled: 0.1412 (0.1583)  cardinality_error_unscaled: 248.5000 (246.6818)  loss_ce_0_unscaled: 1.3984 (1.4048)  loss_bbox_0_unscaled: 0.0495 (0.0481)  loss_giou_0_unscaled: 0.1081 (0.1156)  cardinality_error_0_unscaled: 257.7500 (253.0227)  loss_ce_1_unscaled: 1.1797 (1.1974)  loss_bbox_1_unscaled: 0.0697 (0.0686)  loss_giou_1_unscaled: 0.1395 (0.1458)  cardinality_error_1_unscaled: 240.2500 (233.9091)  loss_ce_enc_unscaled: 1.4609 (1.4496)  loss_bbox_enc_unscaled: 0.0399 (0.0451)  loss_giou_enc_unscaled: 0.1050 (0.1112)  cardinality_error_enc_unscaled: 228.7500 (224.4091)  time: 0.3460  data: 0.0616  max mem: 9121
# Test:  [20/98]  eta: 0:00:27  class_error: 57.14  loss: 7.3995 (7.5002)  loss_ce: 1.1172 (1.1324)  loss_bbox: 0.3689 (0.3980)  loss_giou: 0.3168 (0.3305)  loss_ce_0: 1.4141 (1.4096)  loss_bbox_0: 0.2554 (0.2509)  loss_giou_0: 0.2358 (0.2442)  loss_ce_1: 1.1797 (1.1987)  loss_bbox_1: 0.3485 (0.3455)  loss_giou_1: 0.2846 (0.2993)  loss_ce_enc: 1.4453 (1.4379)  loss_bbox_enc: 0.2021 (0.2244)  loss_giou_enc: 0.2161 (0.2287)  loss_ce_unscaled: 1.1172 (1.1324)  class_error_unscaled: 66.6667 (68.3522)  loss_bbox_unscaled: 0.0738 (0.0796)  loss_giou_unscaled: 0.1584 (0.1652)  cardinality_error_unscaled: 244.7500 (244.2738)  loss_ce_0_unscaled: 1.4141 (1.4096)  loss_bbox_0_unscaled: 0.0511 (0.0502)  loss_giou_0_unscaled: 0.1179 (0.1221)  cardinality_error_0_unscaled: 257.5000 (254.8571)  loss_ce_1_unscaled: 1.1797 (1.1987)  loss_bbox_1_unscaled: 0.0697 (0.0691)  loss_giou_1_unscaled: 0.1423 (0.1497)  cardinality_error_1_unscaled: 229.7500 (232.4524)  loss_ce_enc_unscaled: 1.4453 (1.4379)  loss_bbox_enc_unscaled: 0.0404 (0.0449)  loss_giou_enc_unscaled: 0.1081 (0.1144)  cardinality_error_enc_unscaled: 222.5000 (223.6786)  time: 0.3273  data: 0.0225  max mem: 9121
# Test:  [30/98]  eta: 0:00:22  class_error: 75.00  loss: 7.3963 (7.4949)  loss_ce: 1.1172 (1.1321)  loss_bbox: 0.3861 (0.4005)  loss_giou: 0.3175 (0.3271)  loss_ce_0: 1.3984 (1.4110)  loss_bbox_0: 0.2461 (0.2513)  loss_giou_0: 0.2406 (0.2405)  loss_ce_1: 1.1875 (1.1971)  loss_bbox_1: 0.3346 (0.3537)  loss_giou_1: 0.2941 (0.2988)  loss_ce_enc: 1.4453 (1.4458)  loss_bbox_enc: 0.2010 (0.2189)  loss_giou_enc: 0.2161 (0.2181)  loss_ce_unscaled: 1.1172 (1.1321)  class_error_unscaled: 66.6667 (63.7686)  loss_bbox_unscaled: 0.0772 (0.0801)  loss_giou_unscaled: 0.1587 (0.1636)  cardinality_error_unscaled: 240.5000 (242.1210)  loss_ce_0_unscaled: 1.3984 (1.4110)  loss_bbox_0_unscaled: 0.0492 (0.0503)  loss_giou_0_unscaled: 0.1203 (0.1203)  cardinality_error_0_unscaled: 249.7500 (250.0968)  loss_ce_1_unscaled: 1.1875 (1.1971)  loss_bbox_1_unscaled: 0.0669 (0.0707)  loss_giou_1_unscaled: 0.1470 (0.1494)  cardinality_error_1_unscaled: 229.7500 (231.2419)  loss_ce_enc_unscaled: 1.4453 (1.4458)  loss_bbox_enc_unscaled: 0.0402 (0.0438)  loss_giou_enc_unscaled: 0.1081 (0.1091)  cardinality_error_enc_unscaled: 228.7500 (225.9435)  time: 0.3271  data: 0.0226  max mem: 9121
# Test:  [40/98]  eta: 0:00:19  class_error: 75.00  loss: 7.1728 (7.4208)  loss_ce: 1.1172 (1.1328)  loss_bbox: 0.3791 (0.3894)  loss_giou: 0.2914 (0.3136)  loss_ce_0: 1.3984 (1.4183)  loss_bbox_0: 0.2137 (0.2408)  loss_giou_0: 0.2174 (0.2299)  loss_ce_1: 1.2031 (1.1925)  loss_bbox_1: 0.3380 (0.3467)  loss_giou_1: 0.2758 (0.2897)  loss_ce_enc: 1.4766 (1.4524)  loss_bbox_enc: 0.1858 (0.2086)  loss_giou_enc: 0.1753 (0.2063)  loss_ce_unscaled: 1.1172 (1.1328)  class_error_unscaled: 60.0000 (64.2722)  loss_bbox_unscaled: 0.0758 (0.0779)  loss_giou_unscaled: 0.1457 (0.1568)  cardinality_error_unscaled: 244.2500 (244.7195)  loss_ce_0_unscaled: 1.3984 (1.4183)  loss_bbox_0_unscaled: 0.0427 (0.0482)  loss_giou_0_unscaled: 0.1087 (0.1149)  cardinality_error_0_unscaled: 253.7500 (252.9634)  loss_ce_1_unscaled: 1.2031 (1.1925)  loss_bbox_1_unscaled: 0.0676 (0.0693)  loss_giou_1_unscaled: 0.1379 (0.1449)  cardinality_error_1_unscaled: 234.2500 (233.6585)  loss_ce_enc_unscaled: 1.4766 (1.4524)  loss_bbox_enc_unscaled: 0.0372 (0.0417)  loss_giou_enc_unscaled: 0.0876 (0.1031)  cardinality_error_enc_unscaled: 230.2500 (225.8110)  time: 0.3113  data: 0.0252  max mem: 9121
# Test:  [50/98]  eta: 0:00:15  class_error: 75.00  loss: 7.1888 (7.4231)  loss_ce: 1.0938 (1.1237)  loss_bbox: 0.3828 (0.3930)  loss_giou: 0.2986 (0.3208)  loss_ce_0: 1.3906 (1.4076)  loss_bbox_0: 0.2137 (0.2449)  loss_giou_0: 0.2353 (0.2373)  loss_ce_1: 1.1406 (1.1826)  loss_bbox_1: 0.3582 (0.3510)  loss_giou_1: 0.2931 (0.2980)  loss_ce_enc: 1.4297 (1.4465)  loss_bbox_enc: 0.1936 (0.2089)  loss_giou_enc: 0.1848 (0.2085)  loss_ce_unscaled: 1.0938 (1.1237)  class_error_unscaled: 60.0000 (63.1567)  loss_bbox_unscaled: 0.0766 (0.0786)  loss_giou_unscaled: 0.1493 (0.1604)  cardinality_error_unscaled: 253.0000 (246.6127)  loss_ce_0_unscaled: 1.3906 (1.4076)  loss_bbox_0_unscaled: 0.0427 (0.0490)  loss_giou_0_unscaled: 0.1177 (0.1187)  cardinality_error_0_unscaled: 256.7500 (253.6029)  loss_ce_1_unscaled: 1.1406 (1.1826)  loss_bbox_1_unscaled: 0.0716 (0.0702)  loss_giou_1_unscaled: 0.1465 (0.1490)  cardinality_error_1_unscaled: 236.7500 (235.1324)  loss_ce_enc_unscaled: 1.4297 (1.4465)  loss_bbox_enc_unscaled: 0.0387 (0.0418)  loss_giou_enc_unscaled: 0.0924 (0.1042)  cardinality_error_enc_unscaled: 224.2500 (225.0980)  time: 0.3103  data: 0.0251  max mem: 9121
# Test:  [60/98]  eta: 0:00:12  class_error: 100.00  loss: 7.3026 (7.4077)  loss_ce: 1.0781 (1.1208)  loss_bbox: 0.3695 (0.3886)  loss_giou: 0.3434 (0.3183)  loss_ce_0: 1.3984 (1.4064)  loss_bbox_0: 0.2318 (0.2419)  loss_giou_0: 0.2474 (0.2354)  loss_ce_1: 1.1250 (1.1773)  loss_bbox_1: 0.3740 (0.3564)  loss_giou_1: 0.3461 (0.2993)  loss_ce_enc: 1.4141 (1.4440)  loss_bbox_enc: 0.2040 (0.2092)  loss_giou_enc: 0.2070 (0.2100)  loss_ce_unscaled: 1.0781 (1.1208)  class_error_unscaled: 50.0000 (62.2567)  loss_bbox_unscaled: 0.0739 (0.0777)  loss_giou_unscaled: 0.1717 (0.1592)  cardinality_error_unscaled: 248.0000 (245.6025)  loss_ce_0_unscaled: 1.3984 (1.4064)  loss_bbox_0_unscaled: 0.0464 (0.0484)  loss_giou_0_unscaled: 0.1237 (0.1177)  cardinality_error_0_unscaled: 252.2500 (252.7418)  loss_ce_1_unscaled: 1.1250 (1.1773)  loss_bbox_1_unscaled: 0.0748 (0.0713)  loss_giou_1_unscaled: 0.1730 (0.1496)  cardinality_error_1_unscaled: 234.7500 (234.2008)  loss_ce_enc_unscaled: 1.4141 (1.4440)  loss_bbox_enc_unscaled: 0.0408 (0.0418)  loss_giou_enc_unscaled: 0.1035 (0.1050)  cardinality_error_enc_unscaled: 224.2500 (225.9221)  time: 0.2933  data: 0.0226  max mem: 9121
# Test:  [70/98]  eta: 0:00:09  class_error: 66.67  loss: 7.2688 (7.4086)  loss_ce: 1.1016 (1.1225)  loss_bbox: 0.3391 (0.3854)  loss_giou: 0.3204 (0.3196)  loss_ce_0: 1.3984 (1.4032)  loss_bbox_0: 0.2287 (0.2439)  loss_giou_0: 0.2401 (0.2371)  loss_ce_1: 1.1406 (1.1779)  loss_bbox_1: 0.3654 (0.3527)  loss_giou_1: 0.3078 (0.3001)  loss_ce_enc: 1.4141 (1.4415)  loss_bbox_enc: 0.1975 (0.2124)  loss_giou_enc: 0.2133 (0.2125)  loss_ce_unscaled: 1.1016 (1.1225)  class_error_unscaled: 60.0000 (63.7447)  loss_bbox_unscaled: 0.0678 (0.0771)  loss_giou_unscaled: 0.1602 (0.1598)  cardinality_error_unscaled: 238.0000 (243.8063)  loss_ce_0_unscaled: 1.3984 (1.4032)  loss_bbox_0_unscaled: 0.0457 (0.0488)  loss_giou_0_unscaled: 0.1201 (0.1185)  cardinality_error_0_unscaled: 252.2500 (252.1901)  loss_ce_1_unscaled: 1.1406 (1.1779)  loss_bbox_1_unscaled: 0.0731 (0.0705)  loss_giou_1_unscaled: 0.1539 (0.1501)  cardinality_error_1_unscaled: 226.0000 (233.1021)  loss_ce_enc_unscaled: 1.4141 (1.4415)  loss_bbox_enc_unscaled: 0.0395 (0.0425)  loss_giou_enc_unscaled: 0.1067 (0.1062)  cardinality_error_enc_unscaled: 225.7500 (225.8486)  time: 0.3164  data: 0.0227  max mem: 9121
# Test:  [80/98]  eta: 0:00:05  class_error: 66.67  loss: 7.3130 (7.4045)  loss_ce: 1.1406 (1.1244)  loss_bbox: 0.3395 (0.3821)  loss_giou: 0.3131 (0.3169)  loss_ce_0: 1.3906 (1.4059)  loss_bbox_0: 0.2341 (0.2421)  loss_giou_0: 0.2225 (0.2348)  loss_ce_1: 1.1875 (1.1801)  loss_bbox_1: 0.3367 (0.3519)  loss_giou_1: 0.2975 (0.2995)  loss_ce_enc: 1.4453 (1.4431)  loss_bbox_enc: 0.2092 (0.2117)  loss_giou_enc: 0.2133 (0.2120)  loss_ce_unscaled: 1.1406 (1.1244)  class_error_unscaled: 66.6667 (63.0884)  loss_bbox_unscaled: 0.0679 (0.0764)  loss_giou_unscaled: 0.1565 (0.1585)  cardinality_error_unscaled: 238.2500 (243.8488)  loss_ce_0_unscaled: 1.3906 (1.4059)  loss_bbox_0_unscaled: 0.0468 (0.0484)  loss_giou_0_unscaled: 0.1112 (0.1174)  cardinality_error_0_unscaled: 252.7500 (251.9506)  loss_ce_1_unscaled: 1.1875 (1.1801)  loss_bbox_1_unscaled: 0.0673 (0.0704)  loss_giou_1_unscaled: 0.1487 (0.1498)  cardinality_error_1_unscaled: 230.5000 (233.2006)  loss_ce_enc_unscaled: 1.4453 (1.4431)  loss_bbox_enc_unscaled: 0.0418 (0.0423)  loss_giou_enc_unscaled: 0.1067 (0.1060)  cardinality_error_enc_unscaled: 234.2500 (226.4969)  time: 0.3361  data: 0.0263  max mem: 9121
# Test:  [90/98]  eta: 0:00:02  class_error: 50.00  loss: 7.3130 (7.3982)  loss_ce: 1.1328 (1.1254)  loss_bbox: 0.3613 (0.3813)  loss_giou: 0.3023 (0.3157)  loss_ce_0: 1.3984 (1.4056)  loss_bbox_0: 0.2229 (0.2402)  loss_giou_0: 0.2225 (0.2340)  loss_ce_1: 1.1875 (1.1833)  loss_bbox_1: 0.3375 (0.3473)  loss_giou_1: 0.2883 (0.2977)  loss_ce_enc: 1.4531 (1.4427)  loss_bbox_enc: 0.2239 (0.2131)  loss_giou_enc: 0.2088 (0.2119)  loss_ce_unscaled: 1.1328 (1.1254)  class_error_unscaled: 50.0000 (61.6985)  loss_bbox_unscaled: 0.0723 (0.0763)  loss_giou_unscaled: 0.1512 (0.1579)  cardinality_error_unscaled: 239.7500 (241.9835)  loss_ce_0_unscaled: 1.3984 (1.4056)  loss_bbox_0_unscaled: 0.0446 (0.0480)  loss_giou_0_unscaled: 0.1112 (0.1170)  cardinality_error_0_unscaled: 249.7500 (250.5412)  loss_ce_1_unscaled: 1.1875 (1.1833)  loss_bbox_1_unscaled: 0.0675 (0.0695)  loss_giou_1_unscaled: 0.1441 (0.1488)  cardinality_error_1_unscaled: 231.0000 (231.5742)  loss_ce_enc_unscaled: 1.4531 (1.4427)  loss_bbox_enc_unscaled: 0.0448 (0.0426)  loss_giou_enc_unscaled: 0.1044 (0.1059)  cardinality_error_enc_unscaled: 234.0000 (226.2198)  time: 0.3140  data: 0.0262  max mem: 9121
# Test:  [97/98]  eta: 0:00:00  class_error: 0.00  loss: 7.3130 (7.3919)  loss_ce: 1.1250 (1.1269)  loss_bbox: 0.3395 (0.3782)  loss_giou: 0.2944 (0.3141)  loss_ce_0: 1.3984 (1.4059)  loss_bbox_0: 0.2348 (0.2390)  loss_giou_0: 0.2192 (0.2326)  loss_ce_1: 1.1875 (1.1855)  loss_bbox_1: 0.3330 (0.3451)  loss_giou_1: 0.2843 (0.2961)  loss_ce_enc: 1.4531 (1.4434)  loss_bbox_enc: 0.2242 (0.2135)  loss_giou_enc: 0.1964 (0.2117)  loss_ce_unscaled: 1.1250 (1.1269)  class_error_unscaled: 50.0000 (60.2223)  loss_bbox_unscaled: 0.0679 (0.0756)  loss_giou_unscaled: 0.1472 (0.1571)  cardinality_error_unscaled: 240.7500 (240.9719)  loss_ce_0_unscaled: 1.3984 (1.4059)  loss_bbox_0_unscaled: 0.0470 (0.0478)  loss_giou_0_unscaled: 0.1096 (0.1163)  cardinality_error_0_unscaled: 249.7500 (249.8189)  loss_ce_1_unscaled: 1.1875 (1.1855)  loss_bbox_1_unscaled: 0.0666 (0.0690)  loss_giou_1_unscaled: 0.1421 (0.1480)  cardinality_error_1_unscaled: 231.0000 (230.5102)  loss_ce_enc_unscaled: 1.4531 (1.4434)  loss_bbox_enc_unscaled: 0.0448 (0.0427)  loss_giou_enc_unscaled: 0.0982 (0.1058)  cardinality_error_enc_unscaled: 218.0000 (225.7959)  time: 0.2872  data: 0.0222  max mem: 9121
# Test: Total time: 0:00:31 (0.3179 s / it)
# Averaged stats: class_error: 0.00  loss: 7.3130 (7.3919)  loss_ce: 1.1250 (1.1269)  loss_bbox: 0.3395 (0.3782)  loss_giou: 0.2944 (0.3141)  loss_ce_0: 1.3984 (1.4059)  loss_bbox_0: 0.2348 (0.2390)  loss_giou_0: 0.2192 (0.2326)  loss_ce_1: 1.1875 (1.1855)  loss_bbox_1: 0.3330 (0.3451)  loss_giou_1: 0.2843 (0.2961)  loss_ce_enc: 1.4531 (1.4434)  loss_bbox_enc: 0.2242 (0.2135)  loss_giou_enc: 0.1964 (0.2117)  loss_ce_unscaled: 1.1250 (1.1269)  class_error_unscaled: 50.0000 (60.2223)  loss_bbox_unscaled: 0.0679 (0.0756)  loss_giou_unscaled: 0.1472 (0.1571)  cardinality_error_unscaled: 240.7500 (240.9719)  loss_ce_0_unscaled: 1.3984 (1.4059)  loss_bbox_0_unscaled: 0.0470 (0.0478)  loss_giou_0_unscaled: 0.1096 (0.1163)  cardinality_error_0_unscaled: 249.7500 (249.8189)  loss_ce_1_unscaled: 1.1875 (1.1855)  loss_bbox_1_unscaled: 0.0666 (0.0690)  loss_giou_1_unscaled: 0.1421 (0.1480)  cardinality_error_1_unscaled: 231.0000 (230.5102)  loss_ce_enc_unscaled: 1.4531 (1.4434)  loss_bbox_enc_unscaled: 0.0448 (0.0427)  loss_giou_enc_unscaled: 0.0982 (0.1058)  cardinality_error_enc_unscaled: 218.0000 (225.7959)
# Accumulating evaluation results...
# DONE (t=0.95s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.180
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.266
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.208
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.399
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.179
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.529
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.777
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.799
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.621
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.804
# Training time 0:10:41
# Results saved to output/results.json
# Results saved to output/metrics_plot.png

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

plt.figure(figsize=(12, 8))

plt.plot(
    df['epoch'],
    df['train_loss'],
    label='Training Loss',
    marker='o',
    linestyle='-'
)

plt.plot(
    df['epoch'],
    df['test_loss'],
    label='Validation Loss',
    marker='o',
    linestyle='--'
)

plt.title('Train/Validation Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame(history)

df['avg_precision'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[0])
df['avg_recall'] = df['test_coco_eval_bbox'].apply(lambda arr: arr[6])

plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_precision'],
    marker='o',
    linestyle='-'
)
plt.title('AP (IoU=0.50:0.95, area=all, maxDets=100) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AP')
plt.grid(True)
plt.show()


plt.figure(figsize=(12, 8))
plt.plot(
    df['epoch'],
    df['avg_recall'],
    marker='o',
    linestyle='-'
)
plt.title('AR (IoU=0.50:0.95, area=all, maxDets=1) over Epochs')
plt.xlabel('Epoch')
plt.ylabel('AR')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Run inference with fine-tuned model

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(thickness=thickness)
label_annotator = sv.LabelAnnotator(
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    text_thickness=thickness,
    smart_position=True)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
import supervision as sv
from rfdetr import RFDETRBase
from PIL import Image

detections_images = []

for i in range(16):
    path, image, annotations = ds[i]
    image = Image.open(path)

    detections = model.predict(image, threshold=0.5)

    text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
    thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

    bbox_annotator = sv.BoxAnnotator(thickness=thickness)
    label_annotator = sv.LabelAnnotator(
        text_color=sv.Color.BLACK,
        text_scale=text_scale,
        text_thickness=thickness,
        smart_position=True)

    detections_labels = [
        f"{ds.classes[class_id]} {confidence:.2f}"
        for class_id, confidence
        in zip(detections.class_id, detections.confidence)
    ]

    detections_image = image.copy()
    detections_image = bbox_annotator.annotate(detections_image, detections)
    detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

    detections_images.append(detections_image)

sv.plot_images_grid(images=detections_images, grid_size=(4, 4))

# %% [markdown]
# ## Evaluate fine-tuned model

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0.5)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 193/193 [00:09<00:00, 19.65it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()

map_result.plot()

# %%
confusion_matrix = sv.ConfusionMatrix.from_detections(
    predictions=predictions,
    targets=targets,
    classes=ds.classes
)

_ = confusion_matrix.plot()
